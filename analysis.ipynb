# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
b_p_r_df = pd.read_csv('box_office_profit_rating.csv')
b_p_r_df.plot.scatter('rating','profit')
plt.title('Relationship Between Rating and Profit')
plt.show()

# %%
'''
Correlation Matrix for all three metrics.
'''
b_p_r_df[['BoxOffice', 'profit','rating']].corr()
# Out:
#            BoxOffice    profit    rating
# BoxOffice   1.000000  0.906781 -0.026055
# profit      0.906781  1.000000 -0.046328
# rating     -0.026055 -0.046328  1.000000
